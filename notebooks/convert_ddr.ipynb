# %%
import os
import torch

# %%
path = '../data/DDR/'
folders = [os.path.join(path, f) for f in os.listdir(path) if 'processed' in f]
folders
# Out:
# ['../data/DDR/processed_DDR_valid_SIFT_50',
#  '../data/DDR/processed_DDR_test_SIFT_50',
#  '../data/DDR/processed_DDR_train_LESIONS_encoder_4',
#  '../data/DDR/processed_DDR_test_LESIONS_encoder_4',
#  '../data/DDR/processed_DDR_valid_LESIONS_encoder_4',
#  '../data/DDR/processed_DDR_train_SIFT_50']

# %%
for f in folders:
    data, defaultdict = torch.load(os.path.join(f, 'data.pt'))
    data
# Out:
# ('x', tensor([[22.,  1.,  0.,  ...,  6.,  4.,  0.],
#         [23.,  0.,  0.,  ..., 31., 18., 18.],
#         [ 1.,  0.,  0.,  ...,  1.,  2.,  9.],
#         ...,
#         [ 9., 12., 12.,  ..., 22., 10.,  2.],
#         [48.,  1.,  1.,  ..., 11.,  1.,  0.],
#         [61.,  2.,  0.,  ...,  6.,  3.,  1.]]))
# ('y', tensor([0, 0, 0,  ..., 5, 5, 5]))
# ('pos', tensor([[1328.8536,  299.9901],
#         [ 430.1320,  482.9643],
#         [2007.8685,  831.2510],
#         ...,
#         [1385.7743,  414.4837],
#         [1331.2959,  111.2907],
#         [1384.4294,  138.4872]], dtype=torch.float64))
# ('score', tensor([0.0169, 0.0184, 0.0172,  ..., 0.0116, 0.0126, 0.0113],
#        dtype=torch.float64))
# ...
