# %%
# %load_ext autoreload
# %autoreload 2

import sys

import matplotlib.pyplot as plt
import torch

sys.path.append("../")
import numpy as np

from drgnet.datasets import DDR, Aptos

# %%
aptos = Aptos("../data/aptos", mode="LESIONS", which_features="encoder", feature_layer=4, features_reduction="mean")
ddr = DDR("../data/DDR", mode="LESIONS", which_features="encoder", feature_layer=4, variant="train")

# %%
classes_aptos = []
classes_ddr = []

for d in aptos:
    classes_aptos.append(int(d.y))
for d in ddr:
    classes_ddr.append(int(d.y))

# %%
labels = ["No DR", "Moderate", "Mild", "Severe", "Prolif DR"]

unit, count = np.unique(np.asarray(classes_aptos), return_counts=True)
freq = count / count.sum()

freq = count / count.sum()
plt.bar(labels, freq)
plt.show()

# %%
labels = ["No DR", "Moderate", "Mild", "Severe", "Prolif DR", "Ungradable"]
unit, count = np.unique(np.asarray(classes_ddr), return_counts=True)
freq = count / count.sum()
plt.bar(labels, freq)
plt.show()

# %%
for d in ddr:
    if d.x.shape[0]>5:
        break

# %%
from drgnet.datasets.base import _LesionsTransform
from pathlib import Path

lesions_transform = _LesionsTransform(which_features="encoder", feature_layer=4, features_reduction="mean")

img_path = Path(f"../data/DDR/train/{d.name}.jpg")
print(img_path)
graph = lesions_transform(img_path, int(d.y))
# Out:
# ../data/DDR/train/007-0024-000.jpg

# %%
data1 = graph.x

# %%
data2=graph.x

# %%
data1
# Out:
# tensor([[5.4156e-01, 2.3099e+00, 3.7280e-03,  ..., 0.0000e+00, 1.0715e-02,
#          0.0000e+00],
#         [0.0000e+00, 5.2605e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [3.7369e-01, 3.3875e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [4.6755e-01, 5.4436e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [0.0000e+00, 4.9896e-02, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          4.0000e+00],
#         [7.2135e-01, 4.3076e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00]])

# %%
data2
# Out:
# tensor([[5.4156e-01, 2.3099e+00, 3.7280e-03,  ..., 0.0000e+00, 1.0715e-02,
#          0.0000e+00],
#         [0.0000e+00, 5.2605e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [3.7369e-01, 3.3875e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [4.6755e-01, 5.4436e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00],
#         [0.0000e+00, 4.9896e-02, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          4.0000e+00],
#         [7.2135e-01, 4.3076e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          3.0000e+00]])
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
